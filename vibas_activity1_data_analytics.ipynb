# %% [markdown]
# <a href="https://colab.research.google.com/github/vdhenrey-cmd/Data-Analytics-Program/blob/main/vibas_activity1_data_analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
iris = load_iris()
print(iris.feature_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
print(iris.target_names)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
df = pd.DataFrame (
    iris.data,
    columns=iris.feature_names
)

df ["species"] = iris.target_names [iris.target]
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
print ("Number of rows: ", df.shape[0])
print ("Number of columns: ", df.shape[1])
# Out:
# Number of rows:  150
# Number of columns:  5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64

# %%
print(df["species"].unique())
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
print(df["species"].value_counts())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
plt.figure (figsize=(8, 6))

plt.scatter (
    df["sepal length (cm)"],
    df["sepal width (cm)"],
)
plt.xlabel("sepal length (cm)")
plt.ylabel("Sepal width (cm)")
plt.title("Sepal length vs Sepal width")
plt.show()

# %%
plt.figure (figsize= (8, 6))

for species in df ["species"].unique ():

    subset = df [df ["species"] == species]

    plt.scatter (
        subset ["sepal length (cm)"],
        subset ["sepal width (cm)"],
        label=species
    )

plt.xlabel("sepal length (cm)")
plt.ylabel("sepal width (cm)")
plt.title("Iris species based on Sepal measurements")
plt.legend()
plt.show()

# %%
plt.figure (figsize= (8, 6))

for species in df ["species"].unique ():

    subset = df [df ["species"] == species]

    plt.scatter (
        subset ["petal length (cm)"],
        subset ["petal width (cm)"],
        label=species
    )

plt.xlabel("petal length (cm)")
plt.ylabel("petal width (cm)")
plt.title("Iris species based on Petal measurements")
plt.legend()
plt.show()

# %%
x = iris.data
y = iris.target

x_train, x_yest, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2, random_state=42,
    stratify=y)

print ("Training Observations: ", len (x_train))
print ("Testing Observations: ", len (x_yest))
# Out:
# Training Observations:  120
# Testing Observations:  30

# %%
model = KNeighborsClassifier(n_neighbors=3)

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = model.predict(x_yest)
print (y_pred)
# Out:
# [0 2 1 1 0 1 0 0 2 1 2 2 2 1 0 0 0 1 1 2 0 2 1 2 2 1 1 0 2 0]

# %%
print ("Actual: ")
print (y_test)

print ("\nPredicted: ")
print (y_pred)
# Out:
# Actual:
# [0 2 1 1 0 1 0 0 2 1 2 2 2 1 0 0 0 1 1 2 0 2 1 2 2 1 1 0 2 0]
#
# Predicted:
# [0 2 1 1 0 1 0 0 2 1 2 2 2 1 0 0 0 1 1 2 0 2 1 2 2 1 1 0 2 0]

# %%
accuracy = accuracy_score(y_test, y_pred)
print ("Accuracy: ", accuracy)
# Out:
# Accuracy:  1.0

# %%
new_flower = [[6.0, 2.7, 5.1, 1.6]]

# %%
prediction=model.predict(new_flower)
print("Predicted species: ",
      iris.target_names[prediction[0]]
      )
# Out:
# Predicted species:  virginica

# %%
probabilities = model.predict_proba(new_flower)
print(probabilities)
# Out:
# [[0.         0.33333333 0.66666667]]

# %%
for species, probability in zip (
    iris.target_names,
    probabilities[0]
    ):
    print(f"{species}: {probability * 100:.2f}%")
# Out:
# setosa: 0.00%
# versicolor: 33.33%
# virginica: 66.67%

# %%
k_values = [1,3,5,7,9]
accuracies = []

for k in k_values:
  model = KNeighborsClassifier(n_neighbors=k)
  model.fit(x_train, y_train)
  y_pred = model.predict(x_yest)
  accuracy = accuracy_score(y_test, y_pred)
  accuracies.append(accuracy)
  print(f"K = {k}: Accuracy = {accuracy:2f}")
# Out:
# K = 1: Accuracy = 0.966667
# K = 3: Accuracy = 1.000000
# K = 5: Accuracy = 1.000000
# K = 7: Accuracy = 0.966667
# K = 9: Accuracy = 1.000000

# %%
plt.figure(figsize=(8, 5))
plt.plot(k_values, accuracies, marker='o')
plt.xlabel('K value')
plt.ylabel('Accuracy')
plt.title('KNN Model Accuracy for Different K Values')
plt.xticks(k_values)
plt.show()

# %%
results = pd.DataFrame({
    "Actual": iris.target_names[y_test],
    "Predicted": iris.target_names[y_pred]
})

results.head(10)
# Out:
#        Actual   Predicted
# 0      setosa      setosa
# 1   virginica   virginica
# 2  versicolor  versicolor
# 3  versicolor  versicolor
# 4      setosa      setosa
# 5  versicolor  versicolor
# 6      setosa      setosa
# 7      setosa      setosa
# 8   virginica   virginica
# 9  versicolor  versicolor
